# %%
# import dependencies
import os
import pandas as pd

# %%
# import index csv for datasets
#file_path = "../Datasets/Washington DC/capitalbikeshare_dataset_index.xlsx"
folder_path = '../Datasets/Washington DC/'
file_name = 'capitalbikeshare_dataset_index.csv'
index_df=pd.read_csv(f"{folder_path}{file_name}")

# %%
index_df.head()
# Out:
#    Index  Year                         File Name  Path Note
# 0      0  2010    2010-capitalbikeshare-tripdata   NaN  NaN
# 1      1  2011    2011-capitalbikeshare-tripdata   NaN  NaN
# 2      2  2012  2012Q1-capitalbikeshare-tripdata   NaN  NaN
# 3      3  2012  2012Q2-capitalbikeshare-tripdata   NaN  NaN
# 4      4  2012  2012Q3-capitalbikeshare-tripdata   NaN  NaN

# %%
# Adjust the "Year" column as string data to add 
index_df['Year'] = index_df['Year'].astype(str)
index_df.dtypes
# Out:
# Index          int64
# Year          object
# File Name     object
# Path         float64
# Note          object
# dtype: object

# %%
# variables
i = 0
Year = index_df['Year'][i]+'/'
file_name = index_df['File Name'][i]+'.csv'
file_name = f'{file_name}'
file_name
# Out:
# '2010-capitalbikeshare-tripdata.csv'

# %%
# loop through the 0 to 63 indexes of dataset files we have to import csv files into dataframe
def read_files(i):
    # for i in range(0,65):
        i = 4
        Year = index_df['Year'][i]+'/'
        file_name = index_df['File Name'][i]+'.csv'
        file_name = f'{file_name}'
        folder_path = '../Datasets/Washington DC/'
        folder_path = f"{folder_path}{Year}{file_name}"
        df = pd.read_csv(f"{folder_path}")
        return df
read_files(i)
# Out:
#         Duration           Start date             End date  \
# 0            420  2012-07-01 00:00:08  2012-07-01 00:07:09
# 1            268  2012-07-01 00:00:31  2012-07-01 00:05:00
# 2            494  2012-07-01 00:00:32  2012-07-01 00:08:46
# 3            655  2012-07-01 00:01:34  2012-07-01 00:12:29
# 4           1681  2012-07-01 00:02:06  2012-07-01 00:30:08
# ...          ...                  ...                  ...
# 629912       470  2012-09-30 23:52:04  2012-09-30 23:59:55
# 629913      1048  2012-09-30 23:53:57  2012-10-01 00:11:25
# 629914       430  2012-09-30 23:58:23  2012-10-01 00:05:34
# 629915       292  2012-09-30 23:59:13  2012-10-01 00:04:05
# 629916       323  2012-09-30 23:59:56  2012-10-01 00:05:20
#
#         Start station number                                 Start station  \
# 0                      31104                   Adams Mill & Columbia Rd NW
# 1                      31616                                 3rd & H St NE
# 2                      31307        3000 Connecticut Ave NW / National Zoo
# 3                      31007           Crystal City Metro / 18th & Bell St
# 4                      31235                 19th St & Constitution Ave NW
# ...                      ...                                           ...
# 629912                 31106                      Calvert & Biltmore St NW
# 629913                 31626                15th St & Massachusetts Ave SE
# 629914                 31111                                10th & U St NW
# 629915                 31623               Columbus Circle / Union Station
# 629916                 31610  Eastern Market / 7th & North Carolina Ave SE
#
#         End station number                           End station Bike number  \
# 0                    31200  Massachusetts Ave & Dupont Circle NW      W01155
# 1                    31615                         6th & H St NE      W00405
# 2                    31113           Columbia Rd & Belmont St NW      W00942
# 3                    31002                     20th & Crystal Dr      W01121
# 4                    31222             New York Ave & 15th St NW      W01039
# ...                    ...                                   ...         ...
# 629912               31234         20th & O St NW / Dupont South      W20002
# 629913               31503                 Florida Ave & R St NW      W01456
# 629914               31214                 17th & Corcoran St NW      W00630
# 629915               31604                         3rd & H St NW      W00308
# 629916               31622                        13th & D St NE      W01438
#
#        Member type
# 0           Member
# 1           Member
# 2           Member
# 3           Member
# 4           Casual
# ...            ...
# 629912      Member
# 629913      Member
# 629914      Member
# 629915      Member
# 629916      Member
#
# [629917 rows x 9 columns]
