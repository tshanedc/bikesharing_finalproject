# %%
import pandas as pd
import os

# %%
df = pd.read_csv('./Resources/Washington DC/2010/2010-capitalbikeshare-tripdata.csv')
df.head()
# Out:
#    Duration           Start date             End date  Start station number  \
# 0      1012  2010-09-20 11:27:04  2010-09-20 11:43:56                 31208
# 1        61  2010-09-20 11:41:22  2010-09-20 11:42:23                 31209
# 2      2690  2010-09-20 12:05:37  2010-09-20 12:50:27                 31600
# 3      1406  2010-09-20 12:06:05  2010-09-20 12:29:32                 31600
# 4      1413  2010-09-20 12:10:43  2010-09-20 12:34:17                 31100
#
#                    Start station  End station number  \
# 0       M St & New Jersey Ave SE               31108
# 1                 1st & N St  SE               31209
# 2                  5th & K St NW               31100
# 3                  5th & K St NW               31602
# 4  19th St & Pennsylvania Ave NW               31201
#
#                      End station Bike number Member type
# 0                  4th & M St SW      W00742      Member
# 1                 1st & N St  SE      W00032      Member
# ...

# %%
df.dtypes
# Out:
# Duration                 int64
# Start date              object
# End date                object
# Start station number     int64
# Start station           object
# End station number       int64
# End station             object
# Bike number             object
# Member type             object
# dtype: object

# %%
#If there is nan values
df.isna()
# Out:
#         Duration  Start date  End date  Start station number  Start station  \
# 0          False       False     False                 False          False
# 1          False       False     False                 False          False
# 2          False       False     False                 False          False
# 3          False       False     False                 False          False
# 4          False       False     False                 False          False
# ...          ...         ...       ...                   ...            ...
# 115592     False       False     False                 False          False
# 115593     False       False     False                 False          False
# 115594     False       False     False                 False          False
# 115595     False       False     False                 False          False
# 115596     False       False     False                 False          False
#
# ...

# %%
#If there is null values
df.isnull()
# Out:
#         Duration  Start date  End date  Start station number  Start station  \
# 0          False       False     False                 False          False
# 1          False       False     False                 False          False
# 2          False       False     False                 False          False
# 3          False       False     False                 False          False
# 4          False       False     False                 False          False
# ...          ...         ...       ...                   ...            ...
# 115592     False       False     False                 False          False
# 115593     False       False     False                 False          False
# 115594     False       False     False                 False          False
# 115595     False       False     False                 False          False
# 115596     False       False     False                 False          False
#
# ...

# %%
#Counting null in all columns
df.isnull().sum(axis = 0)
# Out:
# Duration                0
# Start date              0
# End date                0
# Start station number    0
# Start station           0
# End station number      0
# End station             0
# Bike number             0
# Member type             0
# dtype: int64

# %%
#Counting null in all rows
df.isnull().sum(axis = 1)
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 115592    0
# 115593    0
# 115594    0
# 115595    0
# 115596    0
# Length: 115597, dtype: int64

# %%
# rename Pandas columns to lower case
df= df.rename(columns=str.lower)
df
# Out:
#         duration           start date             end date  \
# 0           1012  2010-09-20 11:27:04  2010-09-20 11:43:56
# 1             61  2010-09-20 11:41:22  2010-09-20 11:42:23
# 2           2690  2010-09-20 12:05:37  2010-09-20 12:50:27
# 3           1406  2010-09-20 12:06:05  2010-09-20 12:29:32
# 4           1413  2010-09-20 12:10:43  2010-09-20 12:34:17
# ...          ...                  ...                  ...
# 115592      2179  2010-12-31 23:20:32  2010-12-31 23:56:52
# 115593       953  2010-12-31 23:21:57  2010-12-31 23:37:50
# 115594       737  2010-12-31 23:27:28  2010-12-31 23:39:45
# 115595       514  2010-12-31 23:37:38  2010-12-31 23:46:12
# 115596     51962  2010-12-31 23:49:05  2011-01-01 14:15:08
#
#         start station number                  start station  \
# 0                      31208       M St & New Jersey Ave SE
# 1                      31209                 1st & N St  SE
# 2                      31600                  5th & K St NW
# ...

# %%
# Remove space from column names
df.columns = df.columns.str.replace(' ', '')
df.head()
# Out:
#    duration            startdate              enddate  startstationnumber  \
# 0      1012  2010-09-20 11:27:04  2010-09-20 11:43:56               31208
# 1        61  2010-09-20 11:41:22  2010-09-20 11:42:23               31209
# 2      2690  2010-09-20 12:05:37  2010-09-20 12:50:27               31600
# 3      1406  2010-09-20 12:06:05  2010-09-20 12:29:32               31600
# 4      1413  2010-09-20 12:10:43  2010-09-20 12:34:17               31100
#
#                     startstation  endstationnumber  \
# 0       M St & New Jersey Ave SE             31108
# 1                 1st & N St  SE             31209
# 2                  5th & K St NW             31100
# 3                  5th & K St NW             31602
# 4  19th St & Pennsylvania Ave NW             31201
#
#                       endstation bikenumber membertype
# 0                  4th & M St SW     W00742     Member
# 1                 1st & N St  SE     W00032     Member
# ...

# %%
#Remove the station namubers(they give no information)
#We might also drop bikenumber if we think we dont use it???
df1=df.drop(['startstationnumber', 'endstationnumber', 'bikenumber'], axis=1)

# %%
df = pd.read_csv('./Resources/Washington DC/2011/2011-capitalbikeshare-tripdata.csv')

# %%
# rename Pandas columns to lower case
# Remove space from column names
df.columns = df.columns.str.replace(' ', '')
df= df.rename(columns=str.lower)

# %%
#Remove the station namubers(they give no information)
#We might also drop bikenumber if we think we dont use it???
df2=df.drop(['startstationnumber', 'endstationnumber', 'bikenumber'], axis=1)

# %%
frames = [df1, df2]

# %%
result = pd.concat(frames)

# %%
result
# Out:
#          duration            startdate              enddate  \
# 0            1012  2010-09-20 11:27:04  2010-09-20 11:43:56
# 1              61  2010-09-20 11:41:22  2010-09-20 11:42:23
# 2            2690  2010-09-20 12:05:37  2010-09-20 12:50:27
# 3            1406  2010-09-20 12:06:05  2010-09-20 12:29:32
# 4            1413  2010-09-20 12:10:43  2010-09-20 12:34:17
# ...           ...                  ...                  ...
# 1226762       300  2011-12-31 23:41:19  2011-12-31 23:46:20
# 1226763       387  2011-12-31 23:46:43  2011-12-31 23:53:10
# 1226764       261  2011-12-31 23:47:27  2011-12-31 23:51:49
# 1226765      2060  2011-12-31 23:55:12  2012-01-01 00:29:33
# 1226766       468  2011-12-31 23:55:56  2012-01-01 00:03:45
#
#                               startstation                     endstation  \
# 0                 M St & New Jersey Ave SE                  4th & M St SW
# 1                           1st & N St  SE                 1st & N St  SE
# ...
